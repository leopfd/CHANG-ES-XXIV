# %%
import os
from ciao_contrib.runtool import *
import glob


evtList = sorted(glob.glob("NGC*/*/*/*evt2.fits"))
#print(evtList)

for evt in evtList:
    names = evt.split('/')
    print(names)
    obj = names[0]
    print(obj)
    obsid = names[1]
    print(obsid)
    #print("{}/flux/{}_reproj_evt.fits".format(obj,obsid))
    #print("{}/{}/repro/{}_reproj_evt.fits".format(obj,obsid,obsid))
    os.system('cp {}/flux/{}_reproj_evt.fits {}/{}/repro/{}_reproj_evt.fits'.format(obj,obsid,obj,obsid,obsid))
# Out:
# ['NGC0660', '15333', 'repro', 'acisf15333_repro_evt2.fits']
# NGC0660
# 15333
# ['NGC0660', '15587', 'repro', 'acisf15587_repro_evt2.fits']
# NGC0660
# 15587
# ['NGC0660', '1633', 'repro', 'acisf01633_repro_evt2.fits']
# NGC0660
# 1633
# ['NGC0660', '18352', 'repro', 'acisf18352_repro_evt2.fits']
# NGC0660
# 18352
# ['NGC0660', '4010', 'repro', 'acisf04010_repro_evt2.fits']
# NGC0660
# 4010
# ['NGC0891', '14376', 'repro', 'acisf14376_repro_evt2.fits']
# NGC0891
# 14376
# ['NGC0891', '19297', 'repro', 'acisf19297_repro_evt2.fits']
# NGC0891
# 19297
# ['NGC0891', '4613', 'repro', 'acisf04613_repro_evt2.fits']
# NGC0891
# 4613
# ['NGC0891', '794', 'repro', 'acisf00794_repro_evt2.fits']
# NGC0891
# 794
# ['NGC2683', '11311', 'repro', 'acisf11311_repro_evt2.fits']
# NGC2683
# 11311
# ['NGC2683', '1636', 'repro', 'acisf01636_repro_evt2.fits']
# NGC2683
# 1636
# ['NGC2992', '3956', 'repro', 'acisf03956_repro_corr_evt2.fits']
# NGC2992
# 3956
# ['NGC3079', '19307', 'repro', 'acisf19307_repro_evt2.fits']
# NGC3079
# 19307
# ['NGC3079', '2038', 'repro', 'acisf02038_repro_evt2.fits']
# NGC3079
# 2038
# ['NGC3079', '20947', 'repro', 'acisf20947_repro_evt2.fits']
# NGC3079
# 20947
# ['NGC3432', '7091', 'repro', 'acisf07091_repro_evt2.fits']
# NGC3432
# 7091
# ['NGC3448', '19360', 'repro', 'acisf19360_repro_evt2.fits']
# NGC3448
# 19360
# ['NGC3556', '2025', 'repro', 'acisf02025_repro_evt2.fits']
# NGC3556
# 2025
# ['NGC3628', '2039', 'repro', 'acisf02039_repro_evt2.fits']
# NGC3628
# 2039
# ['NGC3628', '395', 'repro', 'acisf00395_repro_evt2.fits']
# NGC3628
# 395
# ['NGC3877', '1971', 'repro', 'acisf01971_repro_evt2.fits']
# NGC3877
# 1971
# ['NGC3877', '1972', 'repro', 'acisf01972_repro_evt2.fits']
# NGC3877
# 1972
# ['NGC3877', '767', 'repro', 'acisf00767_repro_evt2.fits']
# NGC3877
# 767
# ['NGC3877', '768', 'repro', 'acisf00768_repro_evt2.fits']
# NGC3877
# 768
# ['NGC3877', '952', 'repro', 'acisf00952_repro_evt2.fits']
# NGC3877
# 952
# ['NGC4013', '4013', 'repro', 'acisf04013_repro_evt2.fits']
# NGC4013
# 4013
# ['NGC4013', '4739', 'repro', 'acisf04739_repro_evt2.fits']
# NGC4013
# 4739
# ['NGC4096', '19345', 'repro', 'acisf19345_repro_evt2.fits']
# NGC4096
# 19345
# ['NGC4096', '7103', 'repro', 'acisf07103_repro_evt2.fits']
# NGC4096
# 7103
# ['NGC4157', '11310', 'repro', 'acisf11310_repro_evt2.fits']
# NGC4157
# 11310
# ['NGC4192', '19390', 'repro', 'acisf19390_repro_evt2.fits']
# NGC4192
# 19390
# ['NGC4217', '4738', 'repro', 'acisf04738_repro_evt2.fits']
# NGC4217
# 4738
# ['NGC4244', '942', 'repro', 'acisf00942_repro_evt2.fits']
# NGC4244
# 942
# ['NGC4302', '19392', 'repro', 'acisf19392_repro_evt2.fits']
# NGC4302
# 19392
# ['NGC4302', '19397', 'repro', 'acisf19397_repro_evt2.fits']
# NGC4302
# 19397
# ['NGC4388', '12291', 'repro', 'acisf12291_repro_evt2.fits']
# NGC4388
# 12291
# ['NGC4388', '1619', 'repro', 'acisf01619_repro_evt2.fits']
# NGC4388
# 1619
# ['NGC4438', '2883', 'repro', 'acisf02883_repro_evt2.fits']
# NGC4438
# 2883
# ['NGC4438', '8042', 'repro', 'acisf08042_repro_evt2.fits']
# NGC4438
# 8042
# ['NGC4565', '3950', 'repro', 'acisf03950_repro_evt2.fits']
# NGC4565
# 3950
# ['NGC4565', '404', 'repro', 'acisf00404_repro_evt2.fits']
# NGC4565
# 404
# ['NGC4594', '1586', 'repro', 'acisf01586_repro_evt2.fits']
# NGC4594
# 1586
# ['NGC4594', '407', 'repro', 'acisf00407_repro_evt2.fits']
# NGC4594
# 407
# ['NGC4594', '9532', 'repro', 'acisf09532_repro_evt2.fits']
# NGC4594
# 9532
# ['NGC4594', '9533', 'repro', 'acisf09533_repro_evt2.fits']
# NGC4594
# 9533
# ['NGC4631', '797', 'repro', 'acisf00797_repro_evt2.fits']
# NGC4631
# 797
# ['NGC4666', '4018', 'repro', 'acisf04018_repro_evt2.fits']
# NGC4666
# 4018
# ['NGC5084', '12173', 'repro', 'acisf12173_repro_evt2.fits']
# NGC5084
# 12173
# ['NGC5297', '19370', 'repro', 'acisf19370_repro_evt2.fits']
# NGC5297
# 19370
# ['NGC5775', '2940', 'repro', 'acisf02940_repro_evt2.fits']
# NGC5775
# 2940
# ['NGC5907', '12987', 'repro', 'acisf12987_repro_evt2.fits']
# NGC5907
# 12987
# ['NGC5907', '14391', 'repro', 'acisf14391_repro_evt2.fits']
# NGC5907
# 14391
# ['NGC5907', '20830', 'repro', 'acisf20830_repro_evt2.fits']
# NGC5907
# 20830
# ['NGC5907', '20994', 'repro', 'acisf20994_repro_evt2.fits']
# NGC5907
# 20994
# ['NGC5907', '20995', 'repro', 'acisf20995_repro_evt2.fits']
# NGC5907
# 20995

# %%
cd Wang_Data/
# Out:
# /Users/leo/Wang_Data
